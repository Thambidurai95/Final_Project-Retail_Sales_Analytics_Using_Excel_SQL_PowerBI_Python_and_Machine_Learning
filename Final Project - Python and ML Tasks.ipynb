# %%
# Installing Pandas
# !pip install pandas

# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Installing SQL
# !pip install pymysql

# %%
# Importing sql library
import pymysql

# %%
# Task 1 - Load Data from SQL

# %%
# Connecting with sql database
pymysql.connect(host='127.0.0.1',user='root',passwd='password2924')

# %%
# Storing the newly created connection in the variable
myconnection = pymysql.connect(host='127.0.0.1',user='root',passwd='password2924')

# %%
# Retrieving the customers dataset from sql database with the help of newly created connection
pd.read_sql_query("select * from final_project.customers",myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2064\3827473644.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("select * from final_project.customers",myconnection)
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks              NA
# 1               2       Kasha      Todd              NA
# 2               3      Tameka    Fisher              NA
# 3               4       Daryl    Spence              NA
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison              NA
# 1441         1442      Cassie     Cline              NA
# 1442         1443      Lezlie      Lamb              NA
# 1443         1444      Ivette     Estes              NA
# ...

# %%
# Storing the retrieved customers table in the variable
customers_df = pd.read_sql_query("select * from final_project.customers",myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2064\3003257027.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   customers_df = pd.read_sql_query("select * from final_project.customers",myconnection)

# %%
# Retrieving the orders dataset from sql database with the help of newly created connection
pd.read_sql_query("select * from final_project.orders",myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2064\1888590454.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("select * from final_project.orders",myconnection)
#       order_id  customer_id  order_date required_date shipped_date  store_id  \
# 0            1          259  01-01-2016    03-01-2016   03-01-2016         1
# 1            2         1212  01-01-2016    04-01-2016   03-01-2016         2
# 2            3          523  02-01-2016    05-01-2016   03-01-2016         2
# 3            4          175  03-01-2016    04-01-2016   05-01-2016         1
# 4            5         1324  03-01-2016    06-01-2016   06-01-2016         2
# ...        ...          ...         ...           ...          ...       ...
# 1610      1611            6  06-09-2018    06-09-2018           NA         2
# ...

# %%
# Storing the retrieved orders table in the variable
orders_df = pd.read_sql_query("select * from final_project.orders",myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2064\830610316.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   orders_df = pd.read_sql_query("select * from final_project.orders",myconnection)

# %%
# Retrieving the order_items dataset from sql database with the help of newly created connection
pd.read_sql_query("select * from final_project.order_items",myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2064\2342530962.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("select * from final_project.order_items",myconnection)
#       order_id  item_id  product_id  \
# 0            1        1          20
# 1            1        2           8
# 2            1        3          10
# 3            1        4          16
# 4            1        5           4
# ...        ...      ...         ...
# 4717      1614        2         159
# 4718      1614        3         213
# 4719      1615        1         197
# 4720      1615        2         214
# 4721      1615        3         182
#
#                                         product_name  category_id  \
# 0     Electra Townie Original 7D EQ - Women's - 2016            3
# ...

# %%
# Storing the retrieved order_items table in the variable
order_items_df = pd.read_sql_query("select * from final_project.order_items",myconnection)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2064\1961145598.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_items_df = pd.read_sql_query("select * from final_project.order_items",myconnection)

# %%
# Task 2 - Basic EDA (Exploratory Data Analysis)

# %%
# Dataset Summarization
    # Describe
    # Info
    # Value_counts

# %%
# Customers dataset

# %%
# describe
print(customers_df.describe())
# Out:
#        customer_id
# count  1445.000000
# mean    723.000000
# std     417.279882
# min       1.000000
# 25%     362.000000
# 50%     723.000000
# 75%    1084.000000
# max    1445.000000

# %%
# info
print(customers_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  1445 non-null   int64
#  1   first_name   1445 non-null   object
#  2   last_name    1445 non-null   object
#  3   phone        1445 non-null   object
#  4   email        1445 non-null   object
#  5   street       1445 non-null   object
#  6   city         1445 non-null   object
#  7   state        1445 non-null   object
#  8   zip_code     1445 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 101.7+ KB
# None

# %%
# value_counts
print(customers_df.value_counts())
# Out:
# customer_id  first_name  last_name  phone           email                      street                 city          state  zip_code
# 1            Debra       Burks      NA              debra.burks@yahoo.com      9273 Thorne Ave.       Orchard Park  NY     14127       1
# 972          Damian      Mills      (562) 924-3079  damian.mills@yahoo.com     7747 Elm Dr.           Long Beach    NY     11561       1
# 970          Ruth        Horton     NA              ruth.horton@gmail.com      488 Mulberry Ave.      Hollis        NY     11423       1
# 969          Jennell     Solis      (507) 421-7354  jennell.solis@hotmail.com  194 2nd Rd.            Rochester     NY     14606       1
# 968          Jonna       Brown      NA              jonna.brown@aol.com        1 Spring Drive         Mahopac       NY     10541       1
#                                                                                                                                       ..
# ...

# %%
# Orders Dataset

# %%
# describe
print(orders_df.describe())
# Out:
#           order_id  customer_id     store_id     staff_id
# count  1615.000000  1615.000000  1615.000000  1615.000000
# mean    808.000000   654.171517     1.892260     5.855108
# std     466.354658   443.229967     0.558395     1.913899
# min       1.000000     1.000000     1.000000     2.000000
# 25%     404.500000   237.000000     2.000000     6.000000
# 50%     808.000000   638.000000     2.000000     6.000000
# 75%    1211.500000  1041.500000     2.000000     7.000000
# max    1615.000000  1445.000000     3.000000     9.000000

# %%
# info
print(orders_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1615 non-null   int64
#  1   customer_id    1615 non-null   int64
#  2   order_date     1615 non-null   object
#  3   required_date  1615 non-null   object
#  4   shipped_date   1615 non-null   object
#  5   store_id       1615 non-null   int64
#  6   staff_id       1615 non-null   int64
#  7   order_status   1615 non-null   object
# dtypes: int64(4), object(4)
# memory usage: 101.1+ KB
# None

# %%
# value_counts
print(orders_df.value_counts())
# Out:
# order_id  customer_id  order_date  required_date  shipped_date  store_id  staff_id  order_status
# 1         259          01-01-2016  03-01-2016     03-01-2016    1         2         Delivered       1
# 1074      11           19-08-2017  19-08-2017     NA            2         6         Shipped         1
# 1084      2            21-08-2017  24-08-2017     23-08-2017    1         2         Delivered       1
# 1083      1372         20-08-2017  23-08-2017     23-08-2017    2         6         Delivered       1
# 1082      1327         20-08-2017  22-08-2017     21-08-2017    2         6         Delivered       1
#                                                                                                    ..
# 536       759          31-10-2016  02-11-2016     01-11-2016    1         3         Delivered       1
# 535       835          29-10-2016  31-10-2016     01-11-2016    3         9         Delivered       1
# ...

# %%
# Order_items Dataset

# %%
# describe
print(order_items_df.describe())
# Out:
#           order_id      item_id   product_id  category_id     quantity  \
# count  4722.000000  4722.000000  4722.000000  4722.000000  4722.000000
# mean    821.265354     2.262601    59.366158     3.767471     1.498941
# std     465.152168     1.199129    67.312708     1.985901     0.500052
# min       1.000000     1.000000     2.000000     1.000000     1.000000
# 25%     423.250000     1.000000    14.000000     2.000000     1.000000
# 50%     828.500000     2.000000    28.000000     3.000000     1.000000
# 75%    1226.000000     3.000000    84.000000     6.000000     2.000000
# max    1615.000000     5.000000   315.000000     7.000000     2.000000
#
#          list_price     discount   total_price
# count   4722.000000  4722.000000   4722.000000
# mean    1212.707872     0.105373   1816.707181
# std     1352.798257     0.058119   2228.162327
# min       89.990000     0.050000     89.790000
# 25%      429.000000     0.050000    539.780000
# ...

# %%
# info
print(order_items_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       4722 non-null   int64
#  1   item_id        4722 non-null   int64
#  2   product_id     4722 non-null   int64
#  3   product_name   4722 non-null   object
#  4   category_id    4722 non-null   int64
#  5   category_name  4722 non-null   object
#  6   quantity       4722 non-null   int64
#  7   list_price     4722 non-null   float64
#  8   discount       4722 non-null   float64
#  9   total_price    4722 non-null   float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 369.0+ KB
# None

# %%
# value_counts
print(order_items_df.value_counts())
# Out:
# order_id  item_id  product_id  product_name                                    category_id  category_name      quantity  list_price  discount  total_price
# 1         1        20          Electra Townie Original 7D EQ - Women's - 2016  3            Cruisers Bicycles  1         599.99      0.20      599.79         1
# 1086      5        5           Heller Shagamaw Frame - 2016                    6            Mountain Bikes     1         1320.99     0.20      1320.79        1
# 1092      1        34          Trek Session DH 27.5 Carbon Frameset - 2017     6            Mountain Bikes     1         469.99      0.05      469.94         1
# 1091      3        19          Pure Cycles William 3-Speed - 2016              3            Cruisers Bicycles  1         449.00      0.10      448.90         1
#           2        56          Trek Domane SLR 6 Disc - 2017                   7            Road Bikes         1         5499.99     0.10      5499.89        1
# ...

# %%
# Basic charts plotting

# %%
# Grouping Category name and calculation total revenue through aggregation and sorting the numbers in ascending for creating a plot
order_items_df.groupby(["category_name"]).agg(total_revenue = ("total_price","sum")).sort_values("total_revenue",ascending = [True]).reset_index()
# Out:
#          category_name  total_revenue
# 0    Children Bicycles      327803.83
# 1     Comfort Bicycles      438452.02
# 2  Cyclocross Bicycles      799846.10
# 3       Electric Bikes     1020214.56
# 4    Cruisers Bicycles     1109007.23
# 5           Road Bikes     1852516.12
# 6       Mountain Bikes     3030651.45

# %%
# Storing it in the variable
category_revenue = order_items_df.groupby(["category_name"]).agg(total_revenue = ("total_price","sum")).sort_values("total_revenue",ascending = [True]).reset_index()

# %%
# Bar chart plotting
category_revenue.plot(kind="bar",x="category_name",y="total_revenue",color="black")
# Out:
# <Axes: xlabel='category_name'>

# %%
# Grouping order_status and counting each order status total numbers and sorting it in descending
orders_df.groupby(["order_status"]).agg(Total = ("order_status","count")).sort_values("Total",ascending =[False]).reset_index()
# Out:
#   order_status  Total
# 0    Delivered   1445
# 1   Processing     63
# 2      Pending     62
# 3      Shipped     45

# %%
# Storing it in a variable
order_status_count = orders_df.groupby(["order_status"]).agg(Total = ("order_status","count")).sort_values("Total",ascending =[False]).reset_index()

# %%
# Pie chart plotting
order_status_count.plot(kind="pie",x="order_status",y="Total",color="black")
# Out:
# <Axes: ylabel='Total'>

# %%
# Merging customers and orders dataset using customer_id
pd.merge(customers_df,orders_df,on="customer_id")
# Out:
#       customer_id first_name last_name phone                    email  \
# 0               1      Debra     Burks    NA    debra.burks@yahoo.com
# 1               1      Debra     Burks    NA    debra.burks@yahoo.com
# 2               1      Debra     Burks    NA    debra.burks@yahoo.com
# 3               2      Kasha      Todd    NA     kasha.todd@yahoo.com
# 4               2      Kasha      Todd    NA     kasha.todd@yahoo.com
# ...           ...        ...       ...   ...                      ...
# 1610         1441     Jamaal  Morrison    NA  jamaal.morrison@msn.com
# 1611         1442     Cassie     Cline    NA   cassie.cline@gmail.com
# 1612         1443     Lezlie      Lamb    NA    lezlie.lamb@gmail.com
# 1613         1444     Ivette     Estes    NA   ivette.estes@gmail.com
# 1614         1445      Ester   Acevedo    NA  ester.acevedo@gmail.com
#
#                       street           city state zip_code  order_id  \
# ...

# %%
# Storing it in a variable
customer_orders = pd.merge(customers_df,orders_df,on="customer_id")

# %%
# Grouping state and calculating total orders through aggregation
customer_orders.groupby(["state"]).agg(total_orders = ("order_id","count")).reset_index()
# Out:
#   state  total_orders
# 0    CA           348
# 1    NY          1093
# 2    TX           174

# %%
# Storing it in a variable
state_orders = customer_orders.groupby(["state"]).agg(total_orders = ("order_id","count")).reset_index()

# %%
# Basic chart plotting
plt.plot(state_orders["state"],state_orders["total_orders"])
plt.xlabel("state")
plt.ylabel("total_orders")
plt.title("Total Orders Per State")
plt.show()

# %%
# Importing datetime library
from datetime import datetime

# %%
# Datatype conversion from object to datetime
pd.to_datetime(orders_df['order_date'],format='%d-%m-%Y')
# Out:
# 0      2016-01-01
# 1      2016-01-01
# 2      2016-01-02
# 3      2016-01-03
# 4      2016-01-03
#           ...
# 1610   2018-09-06
# 1611   2018-10-21
# 1612   2018-11-18
# 1613   2018-11-28
# 1614   2018-12-28
# Name: order_date, Length: 1615, dtype: datetime64[ns]

# %%
# Storing it in a variable
orders_df['order_date'] = pd.to_datetime(orders_df['order_date'],format='%d-%m-%Y')

# %%
# Retrieving the order_date from orders with the converted datatype
orders_df['order_date']
# Out:
# 0      2016-01-01
# 1      2016-01-01
# 2      2016-01-02
# 3      2016-01-03
# 4      2016-01-03
#           ...
# 1610   2018-09-06
# 1611   2018-10-21
# 1612   2018-11-18
# 1613   2018-11-28
# 1614   2018-12-28
# Name: order_date, Length: 1615, dtype: datetime64[ns]

# %%
# Task 3 - RFM Calculation for Customers
    # Compute Recency, Frequency, and Monetary values for each customer.
    # Recency: Days since last order
    # Frequency: Number of orders
    # Monetary: Total value of all purchases

# %%
# Merging orders and order_items datasets
pd.merge(orders_df,order_items_df,on='order_id')
# Out:
#       order_id  customer_id order_date required_date shipped_date  store_id  \
# 0            1          259 2016-01-01    03-01-2016   03-01-2016         1
# 1            1          259 2016-01-01    03-01-2016   03-01-2016         1
# 2            1          259 2016-01-01    03-01-2016   03-01-2016         1
# 3            1          259 2016-01-01    03-01-2016   03-01-2016         1
# 4            1          259 2016-01-01    03-01-2016   03-01-2016         1
# ...        ...          ...        ...           ...          ...       ...
# 4717      1614          135 2018-11-28    28-11-2018           NA         3
# 4718      1614          135 2018-11-28    28-11-2018           NA         3
# 4719      1615          136 2018-12-28    28-12-2018           NA         3
# 4720      1615          136 2018-12-28    28-12-2018           NA         3
# 4721      1615          136 2018-12-28    28-12-2018           NA         3
#
#       staff_id order_status  item_id  product_id  \
# ...

# %%
# Storing it in a variable
merged_orders = pd.merge(orders_df,order_items_df,on='order_id')

# %%
# Merging merged_orders and customers datasets
pd.merge(merged_orders,customers_df,on='customer_id')
# Out:
#       order_id  customer_id order_date required_date shipped_date  store_id  \
# 0            1          259 2016-01-01    03-01-2016   03-01-2016         1
# 1            1          259 2016-01-01    03-01-2016   03-01-2016         1
# 2            1          259 2016-01-01    03-01-2016   03-01-2016         1
# 3            1          259 2016-01-01    03-01-2016   03-01-2016         1
# 4            1          259 2016-01-01    03-01-2016   03-01-2016         1
# ...        ...          ...        ...           ...          ...       ...
# 4717      1614          135 2018-11-28    28-11-2018           NA         3
# 4718      1614          135 2018-11-28    28-11-2018           NA         3
# 4719      1615          136 2018-12-28    28-12-2018           NA         3
# 4720      1615          136 2018-12-28    28-12-2018           NA         3
# 4721      1615          136 2018-12-28    28-12-2018           NA         3
#
# ...

# %%
# Storing it in a variable
merged_dataset = pd.merge(merged_orders,customers_df,on='customer_id')

# %%
# Finding the most recent order data and adding one extra date to the max date to freeze the date for date difference
merged_dataset['order_date'].max() + pd.Timedelta(days=1)
# Out:
# Timestamp('2018-12-29 00:00:00')

# %%
# Storing it in a variable
freezed_date = merged_dataset['order_date'].max() + pd.Timedelta(days=1)

# %%
# Grouping the customer_id in the merged_dataset and calculating RFM through aggregation
merged_dataset.groupby('customer_id').agg({
'order_date':lambda x: (freezed_date - x.max()).days,     # recency
'order_id':'nunique',                                     # frequency
'total_price':'sum'                                       # monetary
}).reset_index()
# Out:
#       customer_id  order_date  order_id  total_price
# 0               1          41         3     30644.78
# 1               2         264         3     21652.87
# 2               3          69         3     26248.66
# 3               4         255         3     24197.81
# 4               5         256         3     19442.01
# ...           ...         ...       ...          ...
# 1440         1441         337         1     10497.61
# 1441         1442         517         1      7841.32
# 1442         1443         774         1     11237.59
# 1443         1444         739         1      1749.57
# 1444         1445         297         1      9999.78
#
# [1445 rows x 4 columns]

# %%
# Storing it in a variable
rfm = merged_dataset.groupby('customer_id').agg({
'order_date':lambda x: (freezed_date - x.max()).days,     # recency
'order_id':'nunique',                                     # frequency
'total_price':'sum'                                       # monetary
}).reset_index()

# %%
# Renaming the columns for rfm dataset
rfm.columns = ['customer_id','recency','frequency','monetary']

# %%
# Retrieving rfm dataset with newly updated columns
rfm
# Out:
#       customer_id  recency  frequency  monetary
# 0               1       41          3  30644.78
# 1               2      264          3  21652.87
# 2               3       69          3  26248.66
# 3               4      255          3  24197.81
# 4               5      256          3  19442.01
# ...           ...      ...        ...       ...
# 1440         1441      337          1  10497.61
# 1441         1442      517          1   7841.32
# 1442         1443      774          1  11237.59
# 1443         1444      739          1   1749.57
# 1444         1445      297          1   9999.78
#
# [1445 rows x 4 columns]

# %%
# Retrieving top 5 datas from rfm
print(rfm.head())
# Out:
#    customer_id  recency  frequency  monetary
# 0            1       41          3  30644.78
# 1            2      264          3  21652.87
# 2            3       69          3  26248.66
# 3            4      255          3  24197.81
# 4            5      256          3  19442.01

# %%
# Customer Segmentation using KMeans (Basic Clustering)
    # Use RFM data from above.
    # Normalize using MixMaxScaler.
    # Apply KMeans to segment customers into 3–4 groups.

# %%
# Importing the MinMaxScaler library
from sklearn.preprocessing import MinMaxScaler

# %%
# Scaling method to normalize the range between 0 and 1
MinMaxScaler()
# Out:
# MinMaxScaler()

# %%
# Calculates min-max values of each feature(.fit) and scales the values in to the range [0,1] based on the min-max normalization formula (.transform)
MinMaxScaler().fit_transform(rfm[['recency','frequency','monetary']])
# Out:
# array([[0.03663004, 1.        , 0.81014728],
#        [0.24084249, 1.        , 0.57157484],
#        [0.06227106, 1.        , 0.69350987],
#        ...,
#        [0.70787546, 0.        , 0.29523768],
#        [0.67582418, 0.        , 0.0435025 ],
#        [0.27106227, 0.        , 0.26239623]])

# %%
# Storing it in a variable
rfm_normalized = MinMaxScaler().fit_transform(rfm[['recency','frequency','monetary']])

# %%
# Importing KMeans library
from sklearn.cluster import KMeans

# %%
# Using KMeans library, creating customer segmentaion in to 4 groups by freezing the output with random state of 40 
KMeans(n_clusters=4,random_state=40)
# Out:
# KMeans(n_clusters=4, random_state=40)

# %%
# Storing it in a variable
kmeans = KMeans(n_clusters=4,random_state=40)

# %%
# Train (.fit) and label together (.predict) to cluster
kmeans.fit_predict(rfm_normalized)
# Out:
# array([1, 1, 1, ..., 2, 2, 3])

# %%
# Storing it in a variable
rfm['segment'] = kmeans.fit_predict(rfm_normalized)

# %%
# Retrieving the segment and clusters from rfm for each customers
rfm
# Out:
#       customer_id  recency  frequency  monetary  segment  clusters
# 0               1       41          3  30644.78        1         1
# 1               2      264          3  21652.87        1         1
# 2               3       69          3  26248.66        1         1
# 3               4      255          3  24197.81        1         1
# 4               5      256          3  19442.01        1         1
# ...           ...      ...        ...       ...      ...       ...
# 1440         1441      337          1  10497.61        3         3
# 1441         1442      517          1   7841.32        0         0
# 1442         1443      774          1  11237.59        2         2
# 1443         1444      739          1   1749.57        2         2
# 1444         1445      297          1   9999.78        3         3
#
# [1445 rows x 6 columns]

# %%
# Retrieving rfm[segment] data value counts for each segment
print(rfm['segment'].value_counts())
# Out:
# segment
# 2    602
# 0    534
# 3    179
# 1    130
# Name: count, dtype: int64

# %%
# Scatter plotting for rfm
sns.scatterplot(x='recency',y='monetary',hue='segment',data=rfm)
plt.title('Customer Segments by Recency and Monetary Value')
plt.show()

# %%
# Installing sql library for exporting the data from pandas to sql
# !pip install sqlalchemy pymysql

# %%
# Importing the sql library for exporting the data from pandas to sql
from sqlalchemy import create_engine

# %%
# Creating a connection to a sql database
create_engine('mysql+pymysql://root:password2924@127.0.0.1/final_project')
# Out:
# Engine(mysql+pymysql://root:***@127.0.0.1/final_project)

# %%
# Storing it in a variable
engine = create_engine('mysql+pymysql://root:password2924@127.0.0.1/final_project')

# %%
# Task 5 - Export Segmentation Results to SQL
    # Save the rfm_data with the segment label to SQL as customer_segments table.

# %%
# Exporting the data from pandas to sql
rfm.to_sql('customer_segments',engine,if_exists='replace',index=False)
# Out:
# 1445
